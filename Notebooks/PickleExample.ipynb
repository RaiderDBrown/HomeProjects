# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\Brown Planning\\Downloads\\Correlationdf.csv")
df
# Out:
#                          x                       y   Pearson          Pval
# 0          PayG_Apprentice         PayG_Journeyman  0.997993  1.547077e-14
# 1          PayG_Apprentice     PayG_Junior Officer  0.473414  1.022475e-01
# 2          PayG_Apprentice             PayG_Master  0.989907  1.098301e-10
# 3          PayG_Apprentice  PayG_Mid-Grade Officer -0.034764  9.102308e-01
# 4          PayG_Apprentice            PayG_Warrant  0.100040  7.450507e-01
# ...                    ...                     ...       ...           ...
# 15220  FRPMajorPhaseAbbr_D               Deviation -0.862016  1.509673e-04
# 15221  FRPMajorPhaseAbbr_D              UIC_N23163  0.284268  3.465564e-01
# 15222  FRPMajorPhaseAbbr_S               Deviation  0.862016  1.509673e-04
# 15223  FRPMajorPhaseAbbr_S              UIC_N23163 -0.284268  3.465564e-01
# 15224            Deviation              UIC_N23163  0.039574  8.978655e-01
#
# [15225 rows x 4 columns]

# %%
import pickle
with open('Correlationdf.txt', 'wb') as fh:
   pickle.dump(df, fh)

# %%
pickle_off = open ("Correlationdf.txt", "rb")
pdf = pickle.load(pickle_off)
pdf
# Out:
#                          x                       y   Pearson          Pval
# 0          PayG_Apprentice         PayG_Journeyman  0.997993  1.547077e-14
# 1          PayG_Apprentice     PayG_Junior Officer  0.473414  1.022475e-01
# 2          PayG_Apprentice             PayG_Master  0.989907  1.098301e-10
# 3          PayG_Apprentice  PayG_Mid-Grade Officer -0.034764  9.102308e-01
# 4          PayG_Apprentice            PayG_Warrant  0.100040  7.450507e-01
# ...                    ...                     ...       ...           ...
# 15220  FRPMajorPhaseAbbr_D               Deviation -0.862016  1.509673e-04
# 15221  FRPMajorPhaseAbbr_D              UIC_N23163  0.284268  3.465564e-01
# 15222  FRPMajorPhaseAbbr_S               Deviation  0.862016  1.509673e-04
# 15223  FRPMajorPhaseAbbr_S              UIC_N23163 -0.284268  3.465564e-01
# 15224            Deviation              UIC_N23163  0.039574  8.978655e-01
#
# [15225 rows x 4 columns]
